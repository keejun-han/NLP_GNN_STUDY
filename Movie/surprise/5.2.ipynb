# %%
# Created on Feb 2020
# Author: 임일

import numpy as np
import pandas as pd

# 필요한 Surprise 알고리즘 불러오기
from surprise import BaselineOnly 
from surprise import KNNWithMeans
from surprise import SVD
from surprise import SVDpp
from surprise import NMF
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split

# %%
# MovieLens 100K 데이터 불러오기
data = Dataset.load_builtin('ml-100k')

# Train/Test 분리 
trainset, testset = train_test_split(data, test_size=0.25)
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n]
#  y
# Trying to download dataset from http://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to C:\Users\user/.surprise_data/ml-100k

# %%
# 알고리즘 비교
algorithms = [BaselineOnly, KNNWithMeans, SVD, SVDpp]
names = []
results = []
for option in algorithms:
    algo = option()
    names.append(option.__name__)       # 알고리즘 이름 
    algo.fit(trainset)
    predictions = algo.test(testset)
    results.append(accuracy.rmse(predictions))
names = np.array(names)
results = np.array(results)
# Out:
# Estimating biases using als...
# RMSE: 0.9448
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9492
# RMSE: 0.9387
# RMSE: 0.9191

# %%
# 결과를 그래프로 표시
import matplotlib.pyplot as plt
index = np.argsort(results)
plt.ylim(0.8, 1)
plt.plot(names[index], results[index])
results[index]
# Out:
# array([0.91914782, 0.93874337, 0.94477623, 0.94916471])

# %%
predictions
# Out:
# [Prediction(uid='924', iid='228', r_ui=4.0, est=3.6477975624861, details={'was_impossible': False}),
#  Prediction(uid='889', iid='742', r_ui=3.0, est=3.4094882852916766, details={'was_impossible': False}),
#  Prediction(uid='220', iid='298', r_ui=4.0, est=4.26256534879342, details={'was_impossible': False}),
#  Prediction(uid='332', iid='56', r_ui=5.0, est=4.414326559202703, details={'was_impossible': False}),
#  Prediction(uid='806', iid='155', r_ui=3.0, est=3.1175264992838607, details={'was_impossible': False}),
#  Prediction(uid='59', iid='507', r_ui=4.0, est=4.279435639716684, details={'was_impossible': False}),
#  Prediction(uid='474', iid='510', r_ui=4.0, est=4.543981729749102, details={'was_impossible': False}),
#  Prediction(uid='551', iid='127', r_ui=5.0, est=4.792971325309957, details={'was_impossible': False}),
#  Prediction(uid='444', iid='306', r_ui=5.0, est=3.9383689447332286, details={'was_impossible': False}),
#  Prediction(uid='21', iid='928', r_ui=3.0, est=2.6284634682077046, details={'was_impossible': False}),
#  Prediction(uid='648', iid='444', r_ui=3.0, est=3.0155831738690306, details={'was_impossible': False}),
#  Prediction(uid='271', iid='28', r_ui=5.0, est=3.9835330109521276, details={'was_impossible': False}),
#  Prediction(uid='655', iid='276', r_ui=4.0, est=2.931897741963758, details={'was_impossible': False}),
#  Prediction(uid='617', iid='218', r_ui=2.0, est=2.4663649918456207, details={'was_impossible': False}),
#  Prediction(uid='271', iid='371', r_ui=5.0, est=3.0110023254461127, details={'was_impossible': False}),
#  Prediction(uid='542', iid='367', r_ui=4.0, est=3.6157675517409062, details={'was_impossible': False}),
#  Prediction(uid='450', iid='272', r_ui=5.0, est=4.466203115305057, details={'was_impossible': False}),
#  Prediction(uid='391', iid='134', r_ui=4.0, est=4.339545232614452, details={'was_impossible': False}),
#  Prediction(uid='834', iid='255', r_ui=3.0, est=3.7743819838515873, details={'was_impossible': False}),
#  Prediction(uid='114', iid='56', r_ui=3.0, est=3.6354509497094574, details={'was_impossible': False}),
#  Prediction(uid='409', iid='180', r_ui=5.0, est=4.297743267270943, details={'was_impossible': False}),
#  Prediction(uid='405', iid='569', r_ui=1.0, est=1.8229940018303767, details={'was_impossible': False}),
#  Prediction(uid='194', iid='67', r_ui=1.0, est=2.019592322555971, details={'was_impossible': False}),
#  Prediction(uid='698', iid='434', r_ui=4.0, est=3.264906484391357, details={'was_impossible': False}),
#  Prediction(uid='456', iid='380', r_ui=3.0, est=2.748471955008161, details={'was_impossible': False}),
#  Prediction(uid='592', iid='343', r_ui=3.0, est=2.7782995146854175, details={'was_impossible': False}),
#  Prediction(uid='764', iid='693', r_ui=3.0, est=3.7581412678162263, details={'was_impossible': False}),
#  Prediction(uid='14', iid='524', r_ui=5.0, est=4.2919440450123005, details={'was_impossible': False}),
#  Prediction(uid='253', iid='259', r_ui=2.0, est=2.5343099359372223, details={'was_impossible': False}),
#  Prediction(uid='603', iid='50', r_ui=5.0, est=4.690324485115641, details={'was_impossible': False}),
#  Prediction(uid='26', iid='751', r_ui=4.0, est=2.8853388542018608, details={'was_impossible': False}),
#  Prediction(uid='38', iid='1035', r_ui=5.0, est=3.9503608739148888, details={'was_impossible': False}),
#  Prediction(uid='655', iid='475', r_ui=3.0, est=3.3583202677332604, details={'was_impossible': False}),
#  Prediction(uid='186', iid='226', r_ui=5.0, est=3.8675058634172528, details={'was_impossible': False}),
#  Prediction(uid='269', iid='93', r_ui=3.0, est=3.5594147256206856, details={'was_impossible': False}),
#  Prediction(uid='610', iid='1558', r_ui=3.0, est=3.433884230337307, details={'was_impossible': False}),
#  Prediction(uid='532', iid='268', r_ui=4.0, est=4.077965362670731, details={'was_impossible': False}),
#  Prediction(uid='897', iid='418', r_ui=4.0, est=4.031934352973176, details={'was_impossible': False}),
#  Prediction(uid='247', iid='751', r_ui=3.0, est=3.665999241976843, details={'was_impossible': False}),
#  Prediction(uid='416', iid='392', r_ui=5.0, est=3.7631050489852984, details={'was_impossible': False}),
#  Prediction(uid='503', iid='729', r_ui=3.0, est=3.872316891557147, details={'was_impossible': False}),
#  Prediction(uid='13', iid='810', r_ui=5.0, est=2.153354080752085, details={'was_impossible': False}),
#  Prediction(uid='43', iid='54', r_ui=3.0, est=3.533038890976323, details={'was_impossible': False}),
#  Prediction(uid='620', iid='676', r_ui=3.0, est=3.7654605058853754, details={'was_impossible': False}),
#  Prediction(uid='332', iid='77', r_ui=4.0, est=4.350190839998351, details={'was_impossible': False}),
#  Prediction(uid='468', iid='411', r_ui=3.0, est=3.0551095072937637, details={'was_impossible': False}),
#  Prediction(uid='534', iid='477', r_ui=3.0, est=4.413200949267034, details={'was_impossible': False}),
#  Prediction(uid='109', iid='278', r_ui=3.0, est=3.5348668612675995, details={'was_impossible': False}),
#  Prediction(uid='407', iid='796', r_ui=2.0, est=2.685868187930712, details={'was_impossible': False}),
#  Prediction(uid='128', iid='462', r_ui=4.0, est=3.66957848023098, details={'was_impossible': False}),
#  Prediction(uid='839', iid='455', r_ui=4.0, est=3.1834081257733216, details={'was_impossible': False}),
#  Prediction(uid='194', iid='265', r_ui=4.0, est=3.217138704617509, details={'was_impossible': False}),
#  Prediction(uid='474', iid='124', r_ui=5.0, est=4.576790725065372, details={'was_impossible': False}),
#  Prediction(uid='813', iid='289', r_ui=4.0, est=2.6961122789207126, details={'was_impossible': False}),
#  Prediction(uid='49', iid='2', r_ui=1.0, est=2.270683964748031, details={'was_impossible': False}),
#  Prediction(uid='90', iid='301', r_ui=4.0, est=3.7438164855171507, details={'was_impossible': False}),
#  Prediction(uid='829', iid='284', r_ui=3.0, est=2.7985800481946455, details={'was_impossible': False}),
#  Prediction(uid='360', iid='1', r_ui=3.0, est=3.5389963529991295, details={'was_impossible': False}),
#  Prediction(uid='214', iid='294', r_ui=3.0, est=2.845759304828972, details={'was_impossible': False}),
#  Prediction(uid='57', iid='195', r_ui=3.0, est=4.2812888681360874, details={'was_impossible': False}),
#  Prediction(uid='49', iid='514', r_ui=4.0, est=3.2593186343376397, details={'was_impossible': False}),
#  Prediction(uid='654', iid='735', r_ui=4.0, est=4.234472858549274, details={'was_impossible': False}),
#  Prediction(uid='456', iid='1328', r_ui=4.0, est=3.508559007127743, details={'was_impossible': False}),
#  Prediction(uid='760', iid='288', r_ui=4.0, est=3.425381440161261, details={'was_impossible': False}),
#  Prediction(uid='201', iid='97', r_ui=2.0, est=3.417634884988123, details={'was_impossible': False}),
#  Prediction(uid='927', iid='412', r_ui=1.0, est=3.3400821599087944, details={'was_impossible': False}),
#  Prediction(uid='370', iid='42', r_ui=3.0, est=3.2080219689002414, details={'was_impossible': False}),
#  Prediction(uid='663', iid='1119', r_ui=3.0, est=3.6214076390474297, details={'was_impossible': False}),
#  Prediction(uid='90', iid='154', r_ui=5.0, est=3.9751372853549656, details={'was_impossible': False}),
#  Prediction(uid='790', iid='1016', r_ui=2.0, est=3.1870301923572733, details={'was_impossible': False}),
#  Prediction(uid='548', iid='925', r_ui=2.0, est=3.529422150516496, details={'was_impossible': False}),
#  Prediction(uid='268', iid='163', r_ui=2.0, est=3.435543630043978, details={'was_impossible': False}),
#  Prediction(uid='234', iid='427', r_ui=4.0, est=4.086496386632149, details={'was_impossible': False}),
#  Prediction(uid='896', iid='147', r_ui=2.0, est=3.091241234330835, details={'was_impossible': False}),
#  Prediction(uid='536', iid='480', r_ui=5.0, est=4.358859867793238, details={'was_impossible': False}),
#  Prediction(uid='715', iid='697', r_ui=2.0, est=3.1736965020771586, details={'was_impossible': False}),
#  Prediction(uid='870', iid='218', r_ui=4.0, est=3.054160134137675, details={'was_impossible': False}),
#  Prediction(uid='592', iid='221', r_ui=5.0, est=3.581637374824835, details={'was_impossible': False}),
#  Prediction(uid='159', iid='237', r_ui=3.0, est=4.256864134870052, details={'was_impossible': False}),
#  Prediction(uid='815', iid='91', r_ui=3.0, est=2.9478867121094585, details={'was_impossible': False}),
#  Prediction(uid='833', iid='378', r_ui=3.0, est=2.403726182851389, details={'was_impossible': False}),
#  Prediction(uid='551', iid='265', r_ui=4.0, est=4.527250357712894, details={'was_impossible': False}),
#  Prediction(uid='880', iid='28', r_ui=5.0, est=3.9874112596858167, details={'was_impossible': False}),
#  Prediction(uid='420', iid='127', r_ui=5.0, est=4.508191123869759, details={'was_impossible': False}),
#  Prediction(uid='716', iid='13', r_ui=2.0, est=3.4948018609569114, details={'was_impossible': False}),
#  Prediction(uid='577', iid='284', r_ui=4.0, est=3.3380084831612544, details={'was_impossible': False}),
#  Prediction(uid='588', iid='721', r_ui=5.0, est=3.758116259152747, details={'was_impossible': False}),
#  Prediction(uid='601', iid='65', r_ui=4.0, est=2.9579934434914064, details={'was_impossible': False}),
#  Prediction(uid='543', iid='197', r_ui=4.0, est=3.795086921097615, details={'was_impossible': False}),
#  Prediction(uid='207', iid='192', r_ui=3.0, est=3.2224052432816084, details={'was_impossible': False}),
#  Prediction(uid='934', iid='239', r_ui=4.0, est=3.694716322434491, details={'was_impossible': False}),
#  Prediction(uid='296', iid='150', r_ui=1.0, est=4.19914309625628, details={'was_impossible': False}),
#  Prediction(uid='496', iid='132', r_ui=3.0, est=3.134682611629449, details={'was_impossible': False}),
#  Prediction(uid='70', iid='762', r_ui=3.0, est=3.5563581374308426, details={'was_impossible': False}),
#  Prediction(uid='924', iid='408', r_ui=3.0, est=4.372256299288113, details={'was_impossible': False}),
#  Prediction(uid='487', iid='191', r_ui=4.0, est=4.181108585537369, details={'was_impossible': False}),
#  Prediction(uid='379', iid='90', r_ui=2.0, est=3.5120508987267938, details={'was_impossible': False}),
#  Prediction(uid='901', iid='20', r_ui=1.0, est=3.0658823982737853, details={'was_impossible': False}),
#  Prediction(uid='213', iid='463', r_ui=5.0, est=4.313330540100424, details={'was_impossible': False}),
#  Prediction(uid='111', iid='304', r_ui=4.0, est=3.307120346468566, details={'was_impossible': False}),
#  Prediction(uid='749', iid='609', r_ui=4.0, est=3.7200671744373515, details={'was_impossible': False}),
#  Prediction(uid='53', iid='15', r_ui=5.0, est=3.793107376815952, details={'was_impossible': False}),
#  Prediction(uid='216', iid='134', r_ui=4.0, est=4.610026900702059, details={'was_impossible': False}),
#  Prediction(uid='899', iid='431', r_ui=1.0, est=3.3875869952792783, details={'was_impossible': False}),
#  Prediction(uid='378', iid='417', r_ui=3.0, est=3.175430067102135, details={'was_impossible': False}),
#  Prediction(uid='452', iid='135', r_ui=3.0, est=3.367208683580647, details={'was_impossible': False}),
#  Prediction(uid='776', iid='483', r_ui=5.0, est=4.078338179800018, details={'was_impossible': False}),
#  Prediction(uid='145', iid='301', r_ui=4.0, est=2.4673256133195736, details={'was_impossible': False}),
#  Prediction(uid='712', iid='699', r_ui=5.0, est=3.8022735894010067, details={'was_impossible': False}),
#  Prediction(uid='276', iid='1471', r_ui=2.0, est=2.786314100365761, details={'was_impossible': False}),
#  Prediction(uid='313', iid='222', r_ui=3.0, est=3.8244530964097754, details={'was_impossible': False}),
#  Prediction(uid='712', iid='196', r_ui=4.0, est=4.169307640833492, details={'was_impossible': False}),
#  Prediction(uid='200', iid='196', r_ui=4.0, est=4.525825867841673, details={'was_impossible': False}),
#  Prediction(uid='234', iid='517', r_ui=3.0, est=3.110560937340711, details={'was_impossible': False}),
#  Prediction(uid='130', iid='2', r_ui=4.0, est=4.050554398132363, details={'was_impossible': False}),
#  Prediction(uid='932', iid='1035', r_ui=4.0, est=3.2063766085785232, details={'was_impossible': False}),
#  Prediction(uid='627', iid='228', r_ui=4.0, est=3.20240447066975, details={'was_impossible': False}),
#  Prediction(uid='615', iid='435', r_ui=5.0, est=3.9489734496019673, details={'was_impossible': False}),
#  Prediction(uid='41', iid='181', r_ui=4.0, est=3.707385863484015, details={'was_impossible': False}),
#  Prediction(uid='130', iid='204', r_ui=5.0, est=4.976555928188406, details={'was_impossible': False}),
#  Prediction(uid='713', iid='310', r_ui=4.0, est=2.947408217554587, details={'was_impossible': False}),
#  Prediction(uid='749', iid='72', r_ui=3.0, est=3.4650885675982743, details={'was_impossible': False}),
#  Prediction(uid='502', iid='358', r_ui=4.0, est=2.9357911832165553, details={'was_impossible': False}),
#  Prediction(uid='26', iid='125', r_ui=4.0, est=3.014685364180666, details={'was_impossible': False}),
#  Prediction(uid='204', iid='482', r_ui=4.0, est=3.997530903202136, details={'was_impossible': False}),
#  Prediction(uid='360', iid='45', r_ui=4.0, est=4.213877558084289, details={'was_impossible': False}),
#  Prediction(uid='501', iid='100', r_ui=4.0, est=4.295974044473411, details={'was_impossible': False}),
#  Prediction(uid='295', iid='739', r_ui=4.0, est=4.277309196189385, details={'was_impossible': False}),
#  Prediction(uid='330', iid='584', r_ui=3.0, est=4.027640024860769, details={'was_impossible': False}),
#  Prediction(uid='851', iid='824', r_ui=4.0, est=2.842178196633798, details={'was_impossible': False}),
#  Prediction(uid='280', iid='486', r_ui=5.0, est=3.650977998777839, details={'was_impossible': False}),
#  Prediction(uid='405', iid='422', r_ui=1.0, est=1, details={'was_impossible': False}),
#  Prediction(uid='376', iid='11', r_ui=4.0, est=3.709148852338345, details={'was_impossible': False}),
#  Prediction(uid='417', iid='69', r_ui=3.0, est=4.099867545347889, details={'was_impossible': False}),
#  Prediction(uid='821', iid='484', r_ui=5.0, est=4.963711724390464, details={'was_impossible': False}),
#  Prediction(uid='15', iid='866', r_ui=4.0, est=3.0702677116414803, details={'was_impossible': False}),
#  Prediction(uid='399', iid='722', r_ui=2.0, est=2.605337232093913, details={'was_impossible': False}),
#  Prediction(uid='332', iid='173', r_ui=5.0, est=4.8844008913333905, details={'was_impossible': False}),
#  Prediction(uid='303', iid='1508', r_ui=1.0, est=3.1919411802083175, details={'was_impossible': False}),
#  Prediction(uid='593', iid='122', r_ui=1.0, est=2.0234409252687904, details={'was_impossible': False}),
#  Prediction(uid='784', iid='271', r_ui=3.0, est=3.7748070513103684, details={'was_impossible': False}),
#  Prediction(uid='442', iid='1188', r_ui=3.0, est=2.5068220750132872, details={'was_impossible': False}),
#  Prediction(uid='926', iid='269', r_ui=5.0, est=3.698710257509403, details={'was_impossible': False}),
#  Prediction(uid='494', iid='329', r_ui=3.0, est=3.3957820219596413, details={'was_impossible': False}),
#  Prediction(uid='320', iid='808', r_ui=4.0, est=3.72894937433632, details={'was_impossible': False}),
#  Prediction(uid='427', iid='304', r_ui=4.0, est=4.595926615190864, details={'was_impossible': False}),
#  Prediction(uid='539', iid='372', r_ui=2.0, est=4.067252092215098, details={'was_impossible': False}),
#  Prediction(uid='374', iid='164', r_ui=4.0, est=3.869566048702775, details={'was_impossible': False}),
#  Prediction(uid='201', iid='15', r_ui=3.0, est=2.974368274783722, details={'was_impossible': False}),
#  Prediction(uid='500', iid='742', r_ui=3.0, est=3.21314860236605, details={'was_impossible': False}),
#  Prediction(uid='360', iid='275', r_ui=4.0, est=4.268472114868887, details={'was_impossible': False}),
#  Prediction(uid='592', iid='1059', r_ui=3.0, est=2.8797782989086516, details={'was_impossible': False}),
#  Prediction(uid='548', iid='659', r_ui=4.0, est=3.841695648573711, details={'was_impossible': False}),
#  Prediction(uid='398', iid='127', r_ui=4.0, est=4.076688410934557, details={'was_impossible': False}),
#  Prediction(uid='393', iid='1091', r_ui=2.0, est=2.9232097425675243, details={'was_impossible': False}),
#  Prediction(uid='43', iid='1035', r_ui=4.0, est=3.434229014009114, details={'was_impossible': False}),
#  Prediction(uid='527', iid='190', r_ui=4.0, est=3.8226158069674465, details={'was_impossible': False}),
#  Prediction(uid='886', iid='180', r_ui=5.0, est=3.8678233222521756, details={'was_impossible': False}),
#  Prediction(uid='59', iid='53', r_ui=5.0, est=3.5385489586735765, details={'was_impossible': False}),
#  Prediction(uid='328', iid='628', r_ui=3.0, est=3.3700420624478986, details={'was_impossible': False}),
#  Prediction(uid='234', iid='655', r_ui=3.0, est=3.5958331857332464, details={'was_impossible': False}),
#  Prediction(uid='102', iid='195', r_ui=4.0, est=3.1653606927155247, details={'was_impossible': False}),
#  Prediction(uid='907', iid='271', r_ui=5.0, est=4.02213641841233, details={'was_impossible': False}),
#  Prediction(uid='710', iid='264', r_ui=2.0, est=2.4985752508347248, details={'was_impossible': False}),
#  Prediction(uid='378', iid='288', r_ui=3.0, est=3.242018425963734, details={'was_impossible': False}),
#  Prediction(uid='319', iid='267', r_ui=4.0, est=3.453768368542824, details={'was_impossible': False}),
#  Prediction(uid='776', iid='241', r_ui=1.0, est=3.4720832597233295, details={'was_impossible': False}),
#  Prediction(uid='916', iid='174', r_ui=5.0, est=4.001254873889061, details={'was_impossible': False}),
#  Prediction(uid='396', iid='288', r_ui=3.0, est=4.110476080472148, details={'was_impossible': False}),
#  Prediction(uid='844', iid='121', r_ui=3.0, est=3.161789663970945, details={'was_impossible': False}),
#  Prediction(uid='650', iid='196', r_ui=4.0, est=3.502901927705873, details={'was_impossible': False}),
#  Prediction(uid='632', iid='1183', r_ui=2.0, est=2.5008897426133276, details={'was_impossible': False}),
#  Prediction(uid='393', iid='147', r_ui=5.0, est=3.4290987146595735, details={'was_impossible': False}),
#  Prediction(uid='790', iid='1119', r_ui=4.0, est=3.242030441179094, details={'was_impossible': False}),
#  Prediction(uid='899', iid='28', r_ui=5.0, est=3.679619216499916, details={'was_impossible': False}),
#  Prediction(uid='60', iid='7', r_ui=5.0, est=4.334866996599918, details={'was_impossible': False}),
#  Prediction(uid='747', iid='315', r_ui=4.0, est=4.151968081807564, details={'was_impossible': False}),
#  Prediction(uid='192', iid='515', r_ui=4.0, est=4.442920797107156, details={'was_impossible': False}),
#  Prediction(uid='624', iid='300', r_ui=4.0, est=3.4851029225933448, details={'was_impossible': False}),
#  Prediction(uid='344', iid='716', r_ui=3.0, est=2.930025897165597, details={'was_impossible': False}),
#  Prediction(uid='642', iid='974', r_ui=3.0, est=3.893569187936131, details={'was_impossible': False}),
#  Prediction(uid='758', iid='653', r_ui=3.0, est=4.467715401345096, details={'was_impossible': False}),
#  Prediction(uid='181', iid='815', r_ui=3.0, est=2.060289246471358, details={'was_impossible': False}),
#  Prediction(uid='686', iid='427', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='405', iid='525', r_ui=1.0, est=1.8372119247825303, details={'was_impossible': False}),
#  Prediction(uid='863', iid='751', r_ui=4.0, est=3.4928099845428826, details={'was_impossible': False}),
#  Prediction(uid='405', iid='39', r_ui=1.0, est=1.157929647450882, details={'was_impossible': False}),
#  Prediction(uid='932', iid='665', r_ui=2.0, est=3.4407375134549083, details={'was_impossible': False}),
#  Prediction(uid='758', iid='654', r_ui=4.0, est=4.990983898770043, details={'was_impossible': False}),
#  Prediction(uid='102', iid='577', r_ui=3.0, est=1.583952640406377, details={'was_impossible': False}),
#  Prediction(uid='454', iid='124', r_ui=4.0, est=2.66005658688626, details={'was_impossible': False}),
#  Prediction(uid='392', iid='321', r_ui=5.0, est=3.4296647705030296, details={'was_impossible': False}),
#  Prediction(uid='200', iid='226', r_ui=4.0, est=4.051808195725639, details={'was_impossible': False}),
#  Prediction(uid='588', iid='143', r_ui=5.0, est=4.197617063131382, details={'was_impossible': False}),
#  Prediction(uid='897', iid='193', r_ui=3.0, est=3.9566942974726977, details={'was_impossible': False}),
#  Prediction(uid='347', iid='202', r_ui=4.0, est=4.010516625916415, details={'was_impossible': False}),
#  Prediction(uid='95', iid='176', r_ui=3.0, est=4.185427480936968, details={'was_impossible': False}),
#  Prediction(uid='184', iid='56', r_ui=3.0, est=4.196929710758862, details={'was_impossible': False}),
#  Prediction(uid='694', iid='100', r_ui=4.0, est=4.248148167176868, details={'was_impossible': False}),
#  Prediction(uid='627', iid='227', r_ui=3.0, est=3.1444006488759553, details={'was_impossible': False}),
#  Prediction(uid='682', iid='243', r_ui=1.0, est=1.9547380396310405, details={'was_impossible': False}),
#  Prediction(uid='643', iid='405', r_ui=3.0, est=2.9454007466653445, details={'was_impossible': False}),
#  Prediction(uid='935', iid='476', r_ui=4.0, est=3.609636078543398, details={'was_impossible': False}),
#  Prediction(uid='141', iid='346', r_ui=1.0, est=3.0113675277035727, details={'was_impossible': False}),
#  Prediction(uid='296', iid='246', r_ui=4.0, est=4.238526131152519, details={'was_impossible': False}),
#  Prediction(uid='59', iid='1120', r_ui=1.0, est=3.7026229813454434, details={'was_impossible': False}),
#  Prediction(uid='119', iid='328', r_ui=4.0, est=3.9782638452190526, details={'was_impossible': False}),
#  Prediction(uid='562', iid='143', r_ui=5.0, est=3.8523471759658796, details={'was_impossible': False}),
#  Prediction(uid='731', iid='95', r_ui=3.0, est=3.2490908251001414, details={'was_impossible': False}),
#  Prediction(uid='707', iid='1176', r_ui=2.0, est=3.4905796280226853, details={'was_impossible': False}),
#  Prediction(uid='618', iid='763', r_ui=2.0, est=2.93215547815012, details={'was_impossible': False}),
#  Prediction(uid='393', iid='591', r_ui=5.0, est=4.0046670620170035, details={'was_impossible': False}),
#  Prediction(uid='899', iid='479', r_ui=4.0, est=3.8426992422136372, details={'was_impossible': False}),
#  Prediction(uid='547', iid='340', r_ui=4.0, est=3.485564588964555, details={'was_impossible': False}),
#  Prediction(uid='326', iid='515', r_ui=5.0, est=3.4049718448787534, details={'was_impossible': False}),
#  Prediction(uid='721', iid='455', r_ui=5.0, est=3.6076587541633627, details={'was_impossible': False}),
#  Prediction(uid='833', iid='655', r_ui=2.0, est=3.595160323023764, details={'was_impossible': False}),
#  Prediction(uid='796', iid='196', r_ui=5.0, est=3.822779153649638, details={'was_impossible': False}),
#  Prediction(uid='932', iid='154', r_ui=5.0, est=4.2990368484559776, details={'was_impossible': False}),
#  Prediction(uid='649', iid='181', r_ui=4.0, est=4.447665802198765, details={'was_impossible': False}),
#  Prediction(uid='881', iid='580', r_ui=5.0, est=3.039919254034321, details={'was_impossible': False}),
#  Prediction(uid='452', iid='495', r_ui=4.0, est=3.3965419667410637, details={'was_impossible': False}),
#  Prediction(uid='303', iid='1273', r_ui=2.0, est=2.379876480027625, details={'was_impossible': False}),
#  Prediction(uid='303', iid='31', r_ui=3.0, est=3.700969417992234, details={'was_impossible': False}),
#  Prediction(uid='710', iid='420', r_ui=4.0, est=3.2645944401485574, details={'was_impossible': False}),
#  Prediction(uid='327', iid='333', r_ui=2.0, est=3.4119420128146474, details={'was_impossible': False}),
#  Prediction(uid='587', iid='332', r_ui=4.0, est=3.1286336857685617, details={'was_impossible': False}),
#  Prediction(uid='554', iid='378', r_ui=4.0, est=3.8213412051571205, details={'was_impossible': False}),
#  Prediction(uid='234', iid='280', r_ui=3.0, est=2.314623995745302, details={'was_impossible': False}),
#  Prediction(uid='334', iid='19', r_ui=4.0, est=4.133945267021388, details={'was_impossible': False}),
#  Prediction(uid='667', iid='192', r_ui=5.0, est=3.8038453222834208, details={'was_impossible': False}),
#  Prediction(uid='766', iid='215', r_ui=3.0, est=2.873885222473127, details={'was_impossible': False}),
#  Prediction(uid='198', iid='100', r_ui=1.0, est=3.6546206463782482, details={'was_impossible': False}),
#  Prediction(uid='88', iid='308', r_ui=4.0, est=4.071912673020015, details={'was_impossible': False}),
#  Prediction(uid='854', iid='122', r_ui=3.0, est=2.2664534937288248, details={'was_impossible': False}),
#  Prediction(uid='195', iid='1089', r_ui=4.0, est=1.9071419510137677, details={'was_impossible': False}),
#  Prediction(uid='62', iid='328', r_ui=3.0, est=2.703782571577187, details={'was_impossible': False}),
#  Prediction(uid='254', iid='164', r_ui=4.0, est=3.1462043244384645, details={'was_impossible': False}),
#  Prediction(uid='655', iid='391', r_ui=2.0, est=2.2563746585519437, details={'was_impossible': False}),
#  Prediction(uid='805', iid='241', r_ui=2.0, est=3.093791818611926, details={'was_impossible': False}),
#  Prediction(uid='783', iid='264', r_ui=4.0, est=3.3425442619479457, details={'was_impossible': False}),
#  Prediction(uid='269', iid='1091', r_ui=2.0, est=1.6867614085918172, details={'was_impossible': False}),
#  Prediction(uid='128', iid='422', r_ui=4.0, est=3.0614371248094376, details={'was_impossible': False}),
#  Prediction(uid='110', iid='54', r_ui=4.0, est=3.0544960240244037, details={'was_impossible': False}),
#  Prediction(uid='7', iid='69', r_ui=5.0, est=4.676677661587108, details={'was_impossible': False}),
#  Prediction(uid='488', iid='845', r_ui=3.0, est=3.3382913047861567, details={'was_impossible': False}),
#  Prediction(uid='363', iid='1014', r_ui=1.0, est=2.692021821062781, details={'was_impossible': False}),
#  Prediction(uid='275', iid='144', r_ui=4.0, est=3.2409564777211837, details={'was_impossible': False}),
#  Prediction(uid='130', iid='1280', r_ui=4.0, est=3.521254749437837, details={'was_impossible': False}),
#  Prediction(uid='16', iid='642', r_ui=5.0, est=3.788999540551579, details={'was_impossible': False}),
#  Prediction(uid='58', iid='741', r_ui=2.0, est=3.876312407212881, details={'was_impossible': False}),
#  Prediction(uid='690', iid='64', r_ui=5.0, est=4.146312508017204, details={'was_impossible': False}),
#  Prediction(uid='704', iid='100', r_ui=4.0, est=4.641652299795046, details={'was_impossible': False}),
#  Prediction(uid='246', iid='470', r_ui=4.0, est=3.6338457069066106, details={'was_impossible': False}),
#  Prediction(uid='87', iid='297', r_ui=3.0, est=4.349484243725257, details={'was_impossible': False}),
#  Prediction(uid='500', iid='98', r_ui=4.0, est=3.78527522494355, details={'was_impossible': False}),
#  Prediction(uid='417', iid='288', r_ui=3.0, est=3.8527411653641135, details={'was_impossible': False}),
#  Prediction(uid='426', iid='659', r_ui=4.0, est=4.202855002006265, details={'was_impossible': False}),
#  Prediction(uid='25', iid='50', r_ui=5.0, est=4.353908598440079, details={'was_impossible': False}),
#  Prediction(uid='648', iid='726', r_ui=3.0, est=2.9093434308161346, details={'was_impossible': False}),
#  Prediction(uid='524', iid='116', r_ui=4.0, est=4.233698654791058, details={'was_impossible': False}),
#  Prediction(uid='468', iid='1008', r_ui=4.0, est=3.5745043704561192, details={'was_impossible': False}),
#  Prediction(uid='671', iid='1303', r_ui=3.0, est=2.926333240557273, details={'was_impossible': False}),
#  Prediction(uid='535', iid='735', r_ui=5.0, est=3.95599860105833, details={'was_impossible': False}),
#  Prediction(uid='199', iid='678', r_ui=1.0, est=1.9277154007008526, details={'was_impossible': False}),
#  Prediction(uid='325', iid='1203', r_ui=5.0, est=3.5535470809279412, details={'was_impossible': False}),
#  Prediction(uid='99', iid='1132', r_ui=4.0, est=2.8015984509910385, details={'was_impossible': False}),
#  Prediction(uid='244', iid='69', r_ui=4.0, est=3.7690042169052083, details={'was_impossible': False}),
#  Prediction(uid='293', iid='195', r_ui=3.0, est=3.6874773881312426, details={'was_impossible': False}),
#  Prediction(uid='293', iid='172', r_ui=5.0, est=3.9863435298225047, details={'was_impossible': False}),
#  Prediction(uid='489', iid='351', r_ui=5.0, est=3.5840756217597214, details={'was_impossible': False}),
#  Prediction(uid='747', iid='844', r_ui=4.0, est=3.6997099035413856, details={'was_impossible': False}),
#  Prediction(uid='663', iid='89', r_ui=4.0, est=4.259242199577461, details={'was_impossible': False}),
#  Prediction(uid='396', iid='125', r_ui=3.0, est=4.026556944309398, details={'was_impossible': False}),
#  Prediction(uid='943', iid='739', r_ui=4.0, est=2.955770091864852, details={'was_impossible': False}),
#  Prediction(uid='197', iid='340', r_ui=2.0, est=2.684836000319979, details={'was_impossible': False}),
#  Prediction(uid='459', iid='866', r_ui=5.0, est=3.570265896761546, details={'was_impossible': False}),
#  Prediction(uid='360', iid='582', r_ui=4.0, est=4.018309538579907, details={'was_impossible': False}),
#  Prediction(uid='374', iid='235', r_ui=3.0, est=2.0608960798447686, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1118', r_ui=1.0, est=2.2192467044378184, details={'was_impossible': False}),
#  Prediction(uid='323', iid='273', r_ui=4.0, est=3.7736493408390657, details={'was_impossible': False}),
#  Prediction(uid='721', iid='357', r_ui=5.0, est=3.9795068243688307, details={'was_impossible': False}),
#  Prediction(uid='627', iid='258', r_ui=4.0, est=3.153100186920076, details={'was_impossible': False}),
#  Prediction(uid='293', iid='218', r_ui=2.0, est=2.8805608460975107, details={'was_impossible': False}),
#  Prediction(uid='881', iid='13', r_ui=4.0, est=2.835081569746867, details={'was_impossible': False}),
#  Prediction(uid='270', iid='79', r_ui=4.0, est=4.516682554642021, details={'was_impossible': False}),
#  Prediction(uid='385', iid='719', r_ui=2.0, est=2.4201213581548457, details={'was_impossible': False}),
#  Prediction(uid='83', iid='452', r_ui=3.0, est=3.0440621329707236, details={'was_impossible': False}),
#  Prediction(uid='234', iid='268', r_ui=2.0, est=3.4505814656310445, details={'was_impossible': False}),
#  Prediction(uid='59', iid='474', r_ui=5.0, est=4.843967447361419, details={'was_impossible': False}),
#  Prediction(uid='456', iid='672', r_ui=1.0, est=2.7063676725970653, details={'was_impossible': False}),
#  Prediction(uid='770', iid='50', r_ui=3.0, est=4.939134222717743, details={'was_impossible': False}),
#  Prediction(uid='335', iid='333', r_ui=4.0, est=3.674625649895849, details={'was_impossible': False}),
#  Prediction(uid='184', iid='837', r_ui=3.0, est=3.7877251820700133, details={'was_impossible': False}),
#  Prediction(uid='472', iid='931', r_ui=2.0, est=3.1518123168724292, details={'was_impossible': False}),
#  Prediction(uid='456', iid='475', r_ui=5.0, est=4.45867528266215, details={'was_impossible': False}),
#  Prediction(uid='853', iid='331', r_ui=2.0, est=3.0984460497821216, details={'was_impossible': False}),
#  Prediction(uid='486', iid='1322', r_ui=3.0, est=2.8515296258015916, details={'was_impossible': False}),
#  Prediction(uid='777', iid='521', r_ui=5.0, est=3.4674300119359542, details={'was_impossible': False}),
#  Prediction(uid='683', iid='248', r_ui=4.0, est=3.6495813357084663, details={'was_impossible': False}),
#  Prediction(uid='920', iid='307', r_ui=3.0, est=3.3584358966708154, details={'was_impossible': False}),
#  Prediction(uid='194', iid='944', r_ui=2.0, est=1.9404404768587682, details={'was_impossible': False}),
#  Prediction(uid='12', iid='157', r_ui=5.0, est=4.046888269386521, details={'was_impossible': False}),
#  Prediction(uid='823', iid='50', r_ui=5.0, est=4.945131670839066, details={'was_impossible': False}),
#  Prediction(uid='932', iid='429', r_ui=5.0, est=3.886941958040097, details={'was_impossible': False}),
#  Prediction(uid='454', iid='427', r_ui=4.0, est=3.0733788172669243, details={'was_impossible': False}),
#  Prediction(uid='643', iid='519', r_ui=4.0, est=4.460539997331319, details={'was_impossible': False}),
#  Prediction(uid='276', iid='379', r_ui=3.0, est=3.3084553112811887, details={'was_impossible': False}),
#  Prediction(uid='889', iid='268', r_ui=4.0, est=3.4091121818933185, details={'was_impossible': False}),
#  Prediction(uid='486', iid='307', r_ui=3.0, est=3.0214041208066496, details={'was_impossible': False}),
#  Prediction(uid='648', iid='47', r_ui=2.0, est=3.2400207810179875, details={'was_impossible': False}),
#  Prediction(uid='420', iid='124', r_ui=5.0, est=4.367328127856154, details={'was_impossible': False}),
#  Prediction(uid='911', iid='194', r_ui=4.0, est=4.2156236981017585, details={'was_impossible': False}),
#  Prediction(uid='282', iid='300', r_ui=3.0, est=3.7733566397298666, details={'was_impossible': False}),
#  Prediction(uid='686', iid='28', r_ui=4.0, est=4.074881503529248, details={'was_impossible': False}),
#  Prediction(uid='363', iid='171', r_ui=5.0, est=3.784086761747749, details={'was_impossible': False}),
#  Prediction(uid='864', iid='140', r_ui=3.0, est=3.405979165554937, details={'was_impossible': False}),
#  Prediction(uid='363', iid='42', r_ui=2.0, est=3.523187631329049, details={'was_impossible': False}),
#  Prediction(uid='15', iid='18', r_ui=1.0, est=2.7289639016264378, details={'was_impossible': False}),
#  Prediction(uid='671', iid='11', r_ui=4.0, est=3.6647732733293346, details={'was_impossible': False}),
#  Prediction(uid='63', iid='10', r_ui=4.0, est=3.5981013881659227, details={'was_impossible': False}),
#  Prediction(uid='642', iid='527', r_ui=4.0, est=3.937031960801228, details={'was_impossible': False}),
#  Prediction(uid='782', iid='1380', r_ui=2.0, est=2.5965225824211524, details={'was_impossible': False}),
#  Prediction(uid='330', iid='866', r_ui=5.0, est=4.424006895087198, details={'was_impossible': False}),
#  Prediction(uid='793', iid='406', r_ui=2.0, est=2.5920341149639117, details={'was_impossible': False}),
#  Prediction(uid='474', iid='523', r_ui=5.0, est=4.40300032035969, details={'was_impossible': False}),
#  Prediction(uid='343', iid='237', r_ui=4.0, est=3.295137722931999, details={'was_impossible': False}),
#  Prediction(uid='536', iid='143', r_ui=5.0, est=4.7251892607759824, details={'was_impossible': False}),
#  Prediction(uid='849', iid='588', r_ui=5.0, est=4.732688313052468, details={'was_impossible': False}),
#  Prediction(uid='643', iid='482', r_ui=4.0, est=4.177871293651016, details={'was_impossible': False}),
#  Prediction(uid='218', iid='265', r_ui=3.0, est=3.735680262428073, details={'was_impossible': False}),
#  Prediction(uid='73', iid='657', r_ui=5.0, est=4.160574588604178, details={'was_impossible': False}),
#  Prediction(uid='279', iid='636', r_ui=5.0, est=3.480637364383392, details={'was_impossible': False}),
#  Prediction(uid='536', iid='631', r_ui=2.0, est=3.562151111125087, details={'was_impossible': False}),
#  Prediction(uid='425', iid='62', r_ui=4.0, est=2.5660744129902113, details={'was_impossible': False}),
#  Prediction(uid='119', iid='526', r_ui=2.0, est=4.153723037664187, details={'was_impossible': False}),
#  Prediction(uid='194', iid='234', r_ui=3.0, est=3.4359619053164936, details={'was_impossible': False}),
#  Prediction(uid='222', iid='234', r_ui=2.0, est=3.6413799366237387, details={'was_impossible': False}),
#  Prediction(uid='60', iid='162', r_ui=4.0, est=3.804457090944875, details={'was_impossible': False}),
#  Prediction(uid='435', iid='343', r_ui=5.0, est=3.27436819907615, details={'was_impossible': False}),
#  Prediction(uid='328', iid='161', r_ui=4.0, est=3.8963667904712764, details={'was_impossible': False}),
#  Prediction(uid='252', iid='277', r_ui=4.0, est=3.9688517825681564, details={'was_impossible': False}),
#  Prediction(uid='417', iid='132', r_ui=4.0, est=3.9977491786802566, details={'was_impossible': False}),
#  Prediction(uid='416', iid='930', r_ui=3.0, est=2.959661753742237, details={'was_impossible': False}),
#  Prediction(uid='892', iid='273', r_ui=4.0, est=3.7588002039970143, details={'was_impossible': False}),
#  Prediction(uid='252', iid='100', r_ui=5.0, est=4.7233826347708305, details={'was_impossible': False}),
#  Prediction(uid='347', iid='1028', r_ui=2.0, est=2.840359302883102, details={'was_impossible': False}),
#  Prediction(uid='307', iid='195', r_ui=3.0, est=4.049774595867786, details={'was_impossible': False}),
#  Prediction(uid='561', iid='443', r_ui=4.0, est=3.1103258618617917, details={'was_impossible': False}),
#  Prediction(uid='234', iid='675', r_ui=4.0, est=3.022444962344377, details={'was_impossible': False}),
#  Prediction(uid='22', iid='1001', r_ui=1.0, est=1.409523505977977, details={'was_impossible': False}),
#  Prediction(uid='290', iid='566', r_ui=3.0, est=3.762096691146636, details={'was_impossible': False}),
#  Prediction(uid='429', iid='143', r_ui=3.0, est=3.6753748506896082, details={'was_impossible': False}),
#  Prediction(uid='56', iid='235', r_ui=1.0, est=3.231877899094787, details={'was_impossible': False}),
#  Prediction(uid='385', iid='1495', r_ui=3.0, est=2.9808821304878244, details={'was_impossible': False}),
#  Prediction(uid='280', iid='241', r_ui=2.0, est=3.9394305497903344, details={'was_impossible': False}),
#  Prediction(uid='405', iid='529', r_ui=1.0, est=1.7652154864517065, details={'was_impossible': False}),
#  Prediction(uid='416', iid='1217', r_ui=4.0, est=3.4520298103830296, details={'was_impossible': False}),
#  Prediction(uid='457', iid='155', r_ui=4.0, est=3.4361882107031603, details={'was_impossible': False}),
#  Prediction(uid='714', iid='1152', r_ui=2.0, est=3.7039924555019494, details={'was_impossible': False}),
#  Prediction(uid='326', iid='44', r_ui=1.0, est=3.288082470475671, details={'was_impossible': False}),
#  Prediction(uid='828', iid='640', r_ui=2.0, est=2.229199964349942, details={'was_impossible': False}),
#  Prediction(uid='201', iid='286', r_ui=2.0, est=3.90905573194687, details={'was_impossible': False}),
#  Prediction(uid='13', iid='525', r_ui=5.0, est=4.892932617129111, details={'was_impossible': False}),
#  Prediction(uid='927', iid='222', r_ui=5.0, est=4.291829945341757, details={'was_impossible': False}),
#  Prediction(uid='197', iid='181', r_ui=5.0, est=4.747834450531473, details={'was_impossible': False}),
#  Prediction(uid='718', iid='591', r_ui=4.0, est=3.998149210357875, details={'was_impossible': False}),
#  Prediction(uid='682', iid='280', r_ui=3.0, est=2.759627178963851, details={'was_impossible': False}),
#  Prediction(uid='682', iid='833', r_ui=1.0, est=2.75355196358889, details={'was_impossible': False}),
#  Prediction(uid='537', iid='69', r_ui=2.0, est=2.785441632645579, details={'was_impossible': False}),
#  Prediction(uid='425', iid='272', r_ui=4.0, est=3.2493745536750582, details={'was_impossible': False}),
#  Prediction(uid='91', iid='31', r_ui=5.0, est=3.8042658560156264, details={'was_impossible': False}),
#  Prediction(uid='286', iid='14', r_ui=4.0, est=3.8330956754783836, details={'was_impossible': False}),
#  Prediction(uid='611', iid='750', r_ui=5.0, est=4.3620129048092915, details={'was_impossible': False}),
#  Prediction(uid='215', iid='692', r_ui=3.0, est=3.4865490390139926, details={'was_impossible': False}),
#  Prediction(uid='724', iid='288', r_ui=4.0, est=2.9841806795942967, details={'was_impossible': False}),
#  Prediction(uid='644', iid='250', r_ui=4.0, est=3.7798549323345814, details={'was_impossible': False}),
#  Prediction(uid='87', iid='523', r_ui=5.0, est=4.39921194251333, details={'was_impossible': False}),
#  Prediction(uid='452', iid='480', r_ui=5.0, est=3.822209565327088, details={'was_impossible': False}),
#  Prediction(uid='518', iid='405', r_ui=5.0, est=3.896646927760214, details={'was_impossible': False}),
#  Prediction(uid='741', iid='54', r_ui=3.0, est=3.042203792229166, details={'was_impossible': False}),
#  Prediction(uid='280', iid='866', r_ui=3.0, est=3.1620913417367165, details={'was_impossible': False}),
#  Prediction(uid='896', iid='640', r_ui=2.0, est=2.0499466864120492, details={'was_impossible': False}),
#  Prediction(uid='806', iid='200', r_ui=4.0, est=3.5594954551004485, details={'was_impossible': False}),
#  Prediction(uid='271', iid='539', r_ui=1.0, est=2.1742973591084667, details={'was_impossible': False}),
#  Prediction(uid='548', iid='327', r_ui=3.0, est=3.418670318834329, details={'was_impossible': False}),
#  Prediction(uid='758', iid='737', r_ui=3.0, est=3.4793176551087286, details={'was_impossible': False}),
#  Prediction(uid='779', iid='258', r_ui=5.0, est=4.132540816586041, details={'was_impossible': False}),
#  Prediction(uid='903', iid='210', r_ui=4.0, est=3.6807140304581987, details={'was_impossible': False}),
#  Prediction(uid='873', iid='313', r_ui=5.0, est=3.8941428661177264, details={'was_impossible': False}),
#  Prediction(uid='663', iid='508', r_ui=4.0, est=3.75104786555597, details={'was_impossible': False}),
#  Prediction(uid='474', iid='89', r_ui=5.0, est=4.573891365663988, details={'was_impossible': False}),
#  Prediction(uid='334', iid='29', r_ui=2.0, est=2.2494386517602933, details={'was_impossible': False}),
#  Prediction(uid='268', iid='294', r_ui=3.0, est=2.540838616721578, details={'was_impossible': False}),
#  Prediction(uid='936', iid='327', r_ui=4.0, est=3.828164094922536, details={'was_impossible': False}),
#  Prediction(uid='43', iid='91', r_ui=3.0, est=3.519812986695011, details={'was_impossible': False}),
#  Prediction(uid='18', iid='56', r_ui=5.0, est=3.5649834914937473, details={'was_impossible': False}),
#  Prediction(uid='870', iid='171', r_ui=4.0, est=3.6775457608815305, details={'was_impossible': False}),
#  Prediction(uid='5', iid='439', r_ui=1.0, est=1.8491968788671418, details={'was_impossible': False}),
#  Prediction(uid='622', iid='1', r_ui=3.0, est=4.025705719197726, details={'was_impossible': False}),
#  Prediction(uid='793', iid='250', r_ui=4.0, est=3.8161339865500565, details={'was_impossible': False}),
#  Prediction(uid='676', iid='316', r_ui=4.0, est=4.1032745090377345, details={'was_impossible': False}),
#  Prediction(uid='95', iid='539', r_ui=4.0, est=2.9688042928702973, details={'was_impossible': False}),
#  Prediction(uid='94', iid='467', r_ui=4.0, est=3.884859638199285, details={'was_impossible': False}),
#  Prediction(uid='450', iid='210', r_ui=3.0, est=4.303598260296585, details={'was_impossible': False}),
#  Prediction(uid='868', iid='240', r_ui=5.0, est=2.6035766298982703, details={'was_impossible': False}),
#  Prediction(uid='495', iid='1444', r_ui=2.0, est=3.4251606419600567, details={'was_impossible': False}),
#  Prediction(uid='749', iid='448', r_ui=2.0, est=3.343444937562396, details={'was_impossible': False}),
#  Prediction(uid='66', iid='7', r_ui=3.0, est=3.841768515125901, details={'was_impossible': False}),
#  Prediction(uid='379', iid='210', r_ui=4.0, est=3.939545755720876, details={'was_impossible': False}),
#  Prediction(uid='94', iid='475', r_ui=5.0, est=4.875503309536493, details={'was_impossible': False}),
#  Prediction(uid='249', iid='218', r_ui=3.0, est=3.990425433755475, details={'was_impossible': False}),
#  Prediction(uid='578', iid='678', r_ui=3.0, est=2.5277309857708685, details={'was_impossible': False}),
#  Prediction(uid='594', iid='237', r_ui=3.0, est=3.2189763034033456, details={'was_impossible': False}),
#  Prediction(uid='82', iid='414', r_ui=4.0, est=3.3985099349286254, details={'was_impossible': False}),
#  Prediction(uid='494', iid='427', r_ui=5.0, est=4.537361234396466, details={'was_impossible': False}),
#  Prediction(uid='54', iid='252', r_ui=3.0, est=3.356849859531681, details={'was_impossible': False}),
#  Prediction(uid='130', iid='578', r_ui=5.0, est=4.084018777364367, details={'was_impossible': False}),
#  Prediction(uid='112', iid='984', r_ui=3.0, est=3.1746122945700384, details={'was_impossible': False}),
#  Prediction(uid='303', iid='28', r_ui=3.0, est=4.152709104420792, details={'was_impossible': False}),
#  Prediction(uid='437', iid='211', r_ui=4.0, est=3.8270475988582167, details={'was_impossible': False}),
#  Prediction(uid='913', iid='180', r_ui=3.0, est=3.8279414373040885, details={'was_impossible': False}),
#  Prediction(uid='234', iid='808', r_ui=2.0, est=2.3996841368911457, details={'was_impossible': False}),
#  Prediction(uid='269', iid='616', r_ui=4.0, est=3.2849267081770894, details={'was_impossible': False}),
#  Prediction(uid='747', iid='47', r_ui=5.0, est=4.17928556734303, details={'was_impossible': False}),
#  Prediction(uid='632', iid='356', r_ui=4.0, est=3.237805206345527, details={'was_impossible': False}),
#  Prediction(uid='263', iid='322', r_ui=3.0, est=3.299466725242079, details={'was_impossible': False}),
#  Prediction(uid='363', iid='62', r_ui=2.0, est=2.816429994441511, details={'was_impossible': False}),
#  Prediction(uid='671', iid='219', r_ui=3.0, est=3.3987802770094055, details={'was_impossible': False}),
#  Prediction(uid='456', iid='655', r_ui=3.0, est=3.637032962635269, details={'was_impossible': False}),
#  Prediction(uid='303', iid='172', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='177', iid='271', r_ui=2.0, est=3.4400846471372595, details={'was_impossible': False}),
#  Prediction(uid='598', iid='313', r_ui=5.0, est=4.946631396300063, details={'was_impossible': False}),
#  Prediction(uid='217', iid='222', r_ui=5.0, est=2.6765789837413845, details={'was_impossible': False}),
#  Prediction(uid='933', iid='433', r_ui=1.0, est=2.773969826192599, details={'was_impossible': False}),
#  Prediction(uid='279', iid='1499', r_ui=4.0, est=3.3692693535025717, details={'was_impossible': False}),
#  Prediction(uid='181', iid='117', r_ui=2.0, est=3.0188860584518955, details={'was_impossible': False}),
#  Prediction(uid='645', iid='288', r_ui=3.0, est=3.530558495349051, details={'was_impossible': False}),
#  Prediction(uid='639', iid='166', r_ui=3.0, est=3.444293827418, details={'was_impossible': False}),
#  Prediction(uid='104', iid='249', r_ui=3.0, est=2.7295387959788693, details={'was_impossible': False}),
#  Prediction(uid='201', iid='699', r_ui=3.0, est=3.2091279897005465, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1182', r_ui=1.0, est=1, details={'was_impossible': False}),
#  Prediction(uid='127', iid='901', r_ui=5.0, est=3.0114334786572354, details={'was_impossible': False}),
#  Prediction(uid='249', iid='88', r_ui=4.0, est=3.728093779908378, details={'was_impossible': False}),
#  Prediction(uid='495', iid='167', r_ui=4.0, est=3.435381119032932, details={'was_impossible': False}),
#  Prediction(uid='279', iid='1195', r_ui=1.0, est=3.5003388163910287, details={'was_impossible': False}),
#  Prediction(uid='297', iid='257', r_ui=3.0, est=3.0524792524072, details={'was_impossible': False}),
#  Prediction(uid='648', iid='432', r_ui=5.0, est=3.890865392829696, details={'was_impossible': False}),
#  Prediction(uid='311', iid='43', r_ui=4.0, est=3.3653013006510717, details={'was_impossible': False}),
#  Prediction(uid='49', iid='698', r_ui=2.0, est=2.0744653633971106, details={'was_impossible': False}),
#  Prediction(uid='85', iid='428', r_ui=5.0, est=3.3947651853237484, details={'was_impossible': False}),
#  Prediction(uid='378', iid='202', r_ui=3.0, est=3.6764529065281337, details={'was_impossible': False}),
#  Prediction(uid='271', iid='284', r_ui=3.0, est=3.044791114107909, details={'was_impossible': False}),
#  Prediction(uid='342', iid='298', r_ui=3.0, est=3.4809953458674494, details={'was_impossible': False}),
#  Prediction(uid='854', iid='156', r_ui=3.0, est=3.9940578170533243, details={'was_impossible': False}),
#  Prediction(uid='347', iid='692', r_ui=4.0, est=3.6010499361563544, details={'was_impossible': False}),
#  Prediction(uid='526', iid='1007', r_ui=3.0, est=3.9239245719689473, details={'was_impossible': False}),
#  Prediction(uid='579', iid='1047', r_ui=3.0, est=2.451701033434897, details={'was_impossible': False}),
#  Prediction(uid='425', iid='684', r_ui=2.0, est=3.0758875562062915, details={'was_impossible': False}),
#  Prediction(uid='553', iid='474', r_ui=5.0, est=4.1933070002296855, details={'was_impossible': False}),
#  Prediction(uid='938', iid='106', r_ui=5.0, est=2.8311402591214607, details={'was_impossible': False}),
#  Prediction(uid='227', iid='9', r_ui=3.0, est=4.5596733756931505, details={'was_impossible': False}),
#  Prediction(uid='320', iid='92', r_ui=5.0, est=3.559265512297547, details={'was_impossible': False}),
#  Prediction(uid='265', iid='245', r_ui=4.0, est=3.750786130203856, details={'was_impossible': False}),
#  Prediction(uid='536', iid='31', r_ui=3.0, est=3.851494226423061, details={'was_impossible': False}),
# ...
#  Prediction(uid='819', iid='302', r_ui=5.0, est=4.715699387503838, details={'was_impossible': False}),
#  Prediction(uid='151', iid='176', r_ui=2.0, est=3.9621149956916017, details={'was_impossible': False}),
#  Prediction(uid='660', iid='181', r_ui=4.0, est=3.174240684122011, details={'was_impossible': False}),
#  Prediction(uid='713', iid='1176', r_ui=3.0, est=2.8860259845123277, details={'was_impossible': False}),
#  Prediction(uid='624', iid='690', r_ui=4.0, est=3.6219146253180536, details={'was_impossible': False}),
#  Prediction(uid='885', iid='428', r_ui=4.0, est=3.0242488248603645, details={'was_impossible': False}),
#  Prediction(uid='706', iid='471', r_ui=4.0, est=3.630357162586734, details={'was_impossible': False}),
#  Prediction(uid='907', iid='225', r_ui=5.0, est=4.244505189306294, details={'was_impossible': False}),
#  Prediction(uid='864', iid='202', r_ui=5.0, est=4.2985583557773515, details={'was_impossible': False}),
#  Prediction(uid='244', iid='238', r_ui=5.0, est=4.502660015820252, details={'was_impossible': False}),
#  Prediction(uid='522', iid='133', r_ui=3.0, est=4.342524294797328, details={'was_impossible': False}),
#  Prediction(uid='385', iid='444', r_ui=1.0, est=2.6731399518158296, details={'was_impossible': False}),
#  Prediction(uid='716', iid='204', r_ui=5.0, est=3.849882631497452, details={'was_impossible': False}),
#  Prediction(uid='746', iid='89', r_ui=4.0, est=3.87817914029686, details={'was_impossible': False}),
#  Prediction(uid='26', iid='1013', r_ui=1.0, est=1.6701880976012835, details={'was_impossible': False}),
#  Prediction(uid='328', iid='241', r_ui=5.0, est=4.079539323004106, details={'was_impossible': False}),
#  Prediction(uid='747', iid='194', r_ui=3.0, est=4.382172283142935, details={'was_impossible': False}),
#  Prediction(uid='608', iid='215', r_ui=3.0, est=3.434127370437328, details={'was_impossible': False}),
#  Prediction(uid='117', iid='928', r_ui=3.0, est=3.576106005865336, details={'was_impossible': False}),
#  Prediction(uid='268', iid='226', r_ui=4.0, est=2.375766905807356, details={'was_impossible': False}),
#  Prediction(uid='89', iid='321', r_ui=4.0, est=3.479374285076019, details={'was_impossible': False}),
#  Prediction(uid='541', iid='255', r_ui=3.0, est=3.6359334143985134, details={'was_impossible': False}),
#  Prediction(uid='667', iid='234', r_ui=2.0, est=3.622591587399648, details={'was_impossible': False}),
#  Prediction(uid='151', iid='432', r_ui=5.0, est=4.073674168544303, details={'was_impossible': False}),
#  Prediction(uid='210', iid='204', r_ui=5.0, est=4.176065517578668, details={'was_impossible': False}),
#  Prediction(uid='518', iid='685', r_ui=5.0, est=3.836247573321415, details={'was_impossible': False}),
#  Prediction(uid='77', iid='52', r_ui=5.0, est=3.610642972775219, details={'was_impossible': False}),
#  Prediction(uid='688', iid='754', r_ui=5.0, est=4.693218320241497, details={'was_impossible': False}),
#  Prediction(uid='784', iid='327', r_ui=4.0, est=3.6570990459796495, details={'was_impossible': False}),
#  Prediction(uid='464', iid='258', r_ui=5.0, est=4.083260958316804, details={'was_impossible': False}),
#  Prediction(uid='311', iid='231', r_ui=4.0, est=2.9776099300593297, details={'was_impossible': False}),
#  Prediction(uid='630', iid='276', r_ui=1.0, est=2.465740805697294, details={'was_impossible': False}),
#  Prediction(uid='571', iid='1039', r_ui=3.0, est=3.743457825159151, details={'was_impossible': False}),
#  Prediction(uid='385', iid='273', r_ui=2.0, est=2.8294399222073237, details={'was_impossible': False}),
#  Prediction(uid='567', iid='705', r_ui=5.0, est=3.7922121875657275, details={'was_impossible': False}),
#  Prediction(uid='286', iid='1194', r_ui=4.0, est=4.1382504090461385, details={'was_impossible': False}),
#  Prediction(uid='234', iid='82', r_ui=3.0, est=2.9239164819927903, details={'was_impossible': False}),
#  Prediction(uid='798', iid='815', r_ui=5.0, est=3.4507409002337224, details={'was_impossible': False}),
#  Prediction(uid='788', iid='471', r_ui=3.0, est=3.347894308526957, details={'was_impossible': False}),
#  Prediction(uid='18', iid='520', r_ui=4.0, est=3.8765493217715816, details={'was_impossible': False}),
#  Prediction(uid='20', iid='208', r_ui=2.0, est=3.344764230031152, details={'was_impossible': False}),
#  Prediction(uid='660', iid='83', r_ui=3.0, est=3.40882767496583, details={'was_impossible': False}),
#  Prediction(uid='277', iid='25', r_ui=4.0, est=3.844533453597659, details={'was_impossible': False}),
#  Prediction(uid='621', iid='418', r_ui=3.0, est=3.9671069352085255, details={'was_impossible': False}),
#  Prediction(uid='534', iid='985', r_ui=4.0, est=4.009802878266711, details={'was_impossible': False}),
#  Prediction(uid='28', iid='588', r_ui=3.0, est=3.8635497446470968, details={'was_impossible': False}),
#  Prediction(uid='758', iid='331', r_ui=4.0, est=3.674899718209936, details={'was_impossible': False}),
#  Prediction(uid='682', iid='386', r_ui=2.0, est=2.694359396355303, details={'was_impossible': False}),
#  Prediction(uid='490', iid='293', r_ui=2.0, est=3.041576507835688, details={'was_impossible': False}),
#  Prediction(uid='908', iid='414', r_ui=3.0, est=3.148317004336259, details={'was_impossible': False}),
#  Prediction(uid='497', iid='250', r_ui=3.0, est=3.200694743316094, details={'was_impossible': False}),
#  Prediction(uid='279', iid='114', r_ui=5.0, est=4.056313785813772, details={'was_impossible': False}),
#  Prediction(uid='878', iid='152', r_ui=4.0, est=3.1648130867398305, details={'was_impossible': False}),
#  Prediction(uid='887', iid='432', r_ui=5.0, est=3.3475576852835682, details={'was_impossible': False}),
#  Prediction(uid='89', iid='1119', r_ui=3.0, est=3.71729000021652, details={'was_impossible': False}),
#  Prediction(uid='138', iid='493', r_ui=4.0, est=4.427949175722685, details={'was_impossible': False}),
#  Prediction(uid='1', iid='219', r_ui=1.0, est=3.1100823116374534, details={'was_impossible': False}),
#  Prediction(uid='592', iid='7', r_ui=5.0, est=4.111107210699991, details={'was_impossible': False}),
#  Prediction(uid='92', iid='245', r_ui=4.0, est=2.512988798177436, details={'was_impossible': False}),
#  Prediction(uid='537', iid='616', r_ui=2.0, est=3.1079887316038795, details={'was_impossible': False}),
#  Prediction(uid='267', iid='214', r_ui=4.0, est=3.9434306518885176, details={'was_impossible': False}),
#  Prediction(uid='59', iid='919', r_ui=4.0, est=4.443192468514214, details={'was_impossible': False}),
#  Prediction(uid='175', iid='195', r_ui=3.0, est=3.8138225671316404, details={'was_impossible': False}),
#  Prediction(uid='679', iid='196', r_ui=4.0, est=3.6759411216203075, details={'was_impossible': False}),
#  Prediction(uid='194', iid='647', r_ui=4.0, est=3.1752967533649823, details={'was_impossible': False}),
#  Prediction(uid='726', iid='1059', r_ui=5.0, est=2.5810296638482177, details={'was_impossible': False}),
#  Prediction(uid='484', iid='343', r_ui=2.0, est=3.2588743579262416, details={'was_impossible': False}),
#  Prediction(uid='929', iid='276', r_ui=2.0, est=3.5496850055710043, details={'was_impossible': False}),
#  Prediction(uid='697', iid='263', r_ui=1.0, est=2.6437267906115047, details={'was_impossible': False}),
#  Prediction(uid='498', iid='203', r_ui=5.0, est=3.3844915156733753, details={'was_impossible': False}),
#  Prediction(uid='645', iid='70', r_ui=4.0, est=3.797614372831938, details={'was_impossible': False}),
#  Prediction(uid='813', iid='307', r_ui=4.0, est=3.116654448272726, details={'was_impossible': False}),
#  Prediction(uid='155', iid='990', r_ui=3.0, est=2.8074425265519887, details={'was_impossible': False}),
#  Prediction(uid='13', iid='204', r_ui=5.0, est=3.502035428745769, details={'was_impossible': False}),
#  Prediction(uid='627', iid='530', r_ui=3.0, est=3.866630529665608, details={'was_impossible': False}),
#  Prediction(uid='682', iid='4', r_ui=3.0, est=3.477373163166217, details={'was_impossible': False}),
#  Prediction(uid='712', iid='787', r_ui=3.0, est=3.5749962985678194, details={'was_impossible': False}),
#  Prediction(uid='60', iid='519', r_ui=4.0, est=4.411940747016962, details={'was_impossible': False}),
#  Prediction(uid='405', iid='404', r_ui=4.0, est=2.1189208399939723, details={'was_impossible': False}),
#  Prediction(uid='696', iid='178', r_ui=4.0, est=4.552971072641232, details={'was_impossible': False}),
#  Prediction(uid='83', iid='1041', r_ui=4.0, est=3.4221026312386944, details={'was_impossible': False}),
#  Prediction(uid='160', iid='135', r_ui=4.0, est=4.669935411901328, details={'was_impossible': False}),
#  Prediction(uid='889', iid='729', r_ui=3.0, est=3.0204912744125605, details={'was_impossible': False}),
#  Prediction(uid='407', iid='201', r_ui=4.0, est=3.6561947786274085, details={'was_impossible': False}),
#  Prediction(uid='397', iid='345', r_ui=4.0, est=3.4479232612199673, details={'was_impossible': False}),
#  Prediction(uid='457', iid='96', r_ui=5.0, est=4.3848815116995725, details={'was_impossible': False}),
#  Prediction(uid='757', iid='809', r_ui=4.0, est=3.1195417062845765, details={'was_impossible': False}),
#  Prediction(uid='116', iid='124', r_ui=3.0, est=3.4072118933489968, details={'was_impossible': False}),
#  Prediction(uid='653', iid='622', r_ui=3.0, est=2.182836706663836, details={'was_impossible': False}),
#  Prediction(uid='885', iid='739', r_ui=4.0, est=3.7121056612209395, details={'was_impossible': False}),
#  Prediction(uid='799', iid='292', r_ui=4.0, est=4.098950268885855, details={'was_impossible': False}),
#  Prediction(uid='655', iid='899', r_ui=2.0, est=2.864673382610168, details={'was_impossible': False}),
#  Prediction(uid='741', iid='186', r_ui=5.0, est=3.7165345754489105, details={'was_impossible': False}),
#  Prediction(uid='549', iid='151', r_ui=3.0, est=3.902985842650441, details={'was_impossible': False}),
#  Prediction(uid='425', iid='180', r_ui=4.0, est=3.6831054752521672, details={'was_impossible': False}),
#  Prediction(uid='1', iid='91', r_ui=5.0, est=3.6327115315265313, details={'was_impossible': False}),
#  Prediction(uid='68', iid='50', r_ui=5.0, est=3.77151721597096, details={'was_impossible': False}),
#  Prediction(uid='709', iid='860', r_ui=3.0, est=2.942303618128212, details={'was_impossible': False}),
#  Prediction(uid='933', iid='959', r_ui=1.0, est=2.9901272401629733, details={'was_impossible': False}),
#  Prediction(uid='286', iid='169', r_ui=3.0, est=4.501705976798784, details={'was_impossible': False}),
#  Prediction(uid='69', iid='197', r_ui=5.0, est=4.668140461388445, details={'was_impossible': False}),
#  Prediction(uid='533', iid='393', r_ui=4.0, est=3.614304202143884, details={'was_impossible': False}),
#  Prediction(uid='864', iid='81', r_ui=3.0, est=3.7763012773588356, details={'was_impossible': False}),
#  Prediction(uid='509', iid='343', r_ui=3.0, est=2.1484219061464653, details={'was_impossible': False}),
#  Prediction(uid='771', iid='381', r_ui=3.0, est=3.142311337592705, details={'was_impossible': False}),
#  Prediction(uid='922', iid='155', r_ui=2.0, est=3.2643532797650554, details={'was_impossible': False}),
#  Prediction(uid='497', iid='407', r_ui=2.0, est=2.5330260653291297, details={'was_impossible': False}),
#  Prediction(uid='806', iid='1514', r_ui=3.0, est=3.3031945162297953, details={'was_impossible': False}),
#  Prediction(uid='75', iid='56', r_ui=5.0, est=4.8868076431206315, details={'was_impossible': False}),
#  Prediction(uid='85', iid='1113', r_ui=2.0, est=3.2994783948904955, details={'was_impossible': False}),
#  Prediction(uid='844', iid='175', r_ui=3.0, est=3.4978217484252045, details={'was_impossible': False}),
#  Prediction(uid='378', iid='409', r_ui=2.0, est=3.0394189803551357, details={'was_impossible': False}),
#  Prediction(uid='437', iid='955', r_ui=4.0, est=3.243745203176478, details={'was_impossible': False}),
#  Prediction(uid='825', iid='248', r_ui=4.0, est=3.2033226138141466, details={'was_impossible': False}),
#  Prediction(uid='833', iid='208', r_ui=3.0, est=3.6887590558881507, details={'was_impossible': False}),
#  Prediction(uid='164', iid='742', r_ui=5.0, est=4.681561881088574, details={'was_impossible': False}),
#  Prediction(uid='536', iid='489', r_ui=4.0, est=3.911096967659022, details={'was_impossible': False}),
#  Prediction(uid='548', iid='233', r_ui=5.0, est=3.840483844788883, details={'was_impossible': False}),
#  Prediction(uid='379', iid='577', r_ui=4.0, est=2.134409031645624, details={'was_impossible': False}),
#  Prediction(uid='92', iid='678', r_ui=2.0, est=2.078150684921653, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1367', r_ui=2.0, est=2.1913178444466674, details={'was_impossible': False}),
#  Prediction(uid='405', iid='364', r_ui=1.0, est=1.0226781955905315, details={'was_impossible': False}),
#  Prediction(uid='843', iid='95', r_ui=2.0, est=2.6896596845457665, details={'was_impossible': False}),
#  Prediction(uid='292', iid='132', r_ui=4.0, est=4.641468538912229, details={'was_impossible': False}),
#  Prediction(uid='89', iid='405', r_ui=3.0, est=3.7092687379268354, details={'was_impossible': False}),
#  Prediction(uid='130', iid='542', r_ui=3.0, est=3.257430815756484, details={'was_impossible': False}),
#  Prediction(uid='85', iid='658', r_ui=3.0, est=2.9052530523960134, details={'was_impossible': False}),
#  Prediction(uid='172', iid='183', r_ui=5.0, est=3.1142736128482946, details={'was_impossible': False}),
#  Prediction(uid='404', iid='286', r_ui=1.0, est=3.1778262562895208, details={'was_impossible': False}),
#  Prediction(uid='301', iid='174', r_ui=5.0, est=4.522796442314374, details={'was_impossible': False}),
#  Prediction(uid='68', iid='288', r_ui=4.0, est=2.5495531175921924, details={'was_impossible': False}),
#  Prediction(uid='299', iid='288', r_ui=3.0, est=2.802031772176954, details={'was_impossible': False}),
#  Prediction(uid='862', iid='633', r_ui=5.0, est=4.658609694209127, details={'was_impossible': False}),
#  Prediction(uid='706', iid='24', r_ui=3.0, est=3.0168680900977565, details={'was_impossible': False}),
#  Prediction(uid='256', iid='925', r_ui=5.0, est=4.1174163877934316, details={'was_impossible': False}),
#  Prediction(uid='728', iid='508', r_ui=4.0, est=3.7845280170256204, details={'was_impossible': False}),
#  Prediction(uid='305', iid='186', r_ui=4.0, est=3.0477626217134794, details={'was_impossible': False}),
#  Prediction(uid='474', iid='423', r_ui=5.0, est=4.504152016356418, details={'was_impossible': False}),
#  Prediction(uid='865', iid='547', r_ui=5.0, est=2.6371697831507457, details={'was_impossible': False}),
#  Prediction(uid='145', iid='628', r_ui=2.0, est=3.5950070472851587, details={'was_impossible': False}),
#  Prediction(uid='417', iid='562', r_ui=4.0, est=2.7266032968472076, details={'was_impossible': False}),
#  Prediction(uid='498', iid='258', r_ui=2.0, est=2.5257859768751927, details={'was_impossible': False}),
#  Prediction(uid='98', iid='514', r_ui=5.0, est=3.473053675900183, details={'was_impossible': False}),
#  Prediction(uid='488', iid='485', r_ui=3.0, est=3.406184760990132, details={'was_impossible': False}),
#  Prediction(uid='176', iid='150', r_ui=4.0, est=3.8439200037495, details={'was_impossible': False}),
#  Prediction(uid='688', iid='338', r_ui=5.0, est=4.5936048893027275, details={'was_impossible': False}),
#  Prediction(uid='378', iid='663', r_ui=3.0, est=3.835531972708859, details={'was_impossible': False}),
#  Prediction(uid='496', iid='480', r_ui=3.0, est=3.811272019781593, details={'was_impossible': False}),
#  Prediction(uid='156', iid='124', r_ui=3.0, est=4.101838036446647, details={'was_impossible': False}),
#  Prediction(uid='542', iid='89', r_ui=4.0, est=3.9548430135619115, details={'was_impossible': False}),
#  Prediction(uid='81', iid='98', r_ui=5.0, est=4.247851954990467, details={'was_impossible': False}),
#  Prediction(uid='699', iid='276', r_ui=3.0, est=3.2998773789210607, details={'was_impossible': False}),
#  Prediction(uid='927', iid='367', r_ui=5.0, est=3.884162460079189, details={'was_impossible': False}),
#  Prediction(uid='76', iid='60', r_ui=4.0, est=4.009679662714725, details={'was_impossible': False}),
#  ...]
